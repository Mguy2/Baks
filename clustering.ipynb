# %% [markdown]
# ---
#
# # **Moore MKW - Anomaly Detection in Product Prices**
# ### **A pilot project using crawled Keessmit product data**
#
# ### Moni IT & Consultancy
#
# ### Gert Wijnalda, M.M.J.D.T. Voeten
#
# ---

# %% [markdown]
# ---
#
# # **1.0 - Project Goal**
#
# ---

# %% [markdown]
# - To detect anomalies in product prices.
# - Find out whether automatisation of anomaly detection in addition to randomized checks could lead to improved confidence in audits while reducing auditor workloads.

# %% [markdown]
# ---
#
# # **2.0 - Dataset Description**
#
# ---

# %% [markdown]
# <style>
#   table {
#     margin: auto;
#     width: 100%;
#   }
#   td {
#     text-align: justify;
#     padding: 8px;
#   }
#   th
#   {
#     text-align: center;
#   }
# </style>
#
# ---
#
# <table> <tr> <th> Feature </th> <th> Description </th> </tr> <tr> <td> productID </td> <td> Unique identifier assigned to each product. </td> </tr> <tr> <td> productName </td> <td> Full descriptive name of the product, often including specifications or value (e.g., "Shadowline Parasol beschermhoes Small"). </td> </tr> <tr> <td> productPrice </td> <td> Listed retail price of the product, expressed in local currency. </td> </tr> <tr> <td> productVAT </td> <td> Value Added Tax (VAT) applicable to the product, if available. </td> </tr> <tr> <td> productDiscount </td> <td> Discount offered on the product, typically expressed as a percentage reduction (e.g., "-15%"). </td> </tr> <tr> <td> productColor </td> <td> Color or combination of colors of the product (e.g., "Grijs - Antraciet"). </td> </tr> <tr> <td> productCategory </td> <td> Product category or grouping, indicating the type of item (e.g., "Parasols", "Tuinstoelen"). </td> </tr> <tr> <td> productBrand </td> <td> Brand or manufacturer associated with the product. </td> </tr> <tr> <td> productURL </td> <td> Website link to the product’s detail page. </td> </tr> <tr> <td> currentDate </td> <td> Timestamp indicating when the product information was collected or recorded. </td> </tr> </table><br>

# %% [markdown]
# ---
#
# # **3.0 - Methodology**
#
# ---

# %% [markdown]
# TODO

# %% [markdown]
# ---
#
# # **4.0 - Imports & Preliminaries**
#
# ---

# %%
#%pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: numpy<2 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: openpyxl in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: matplotlib>=3.9.2 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: seaborn>=0.13.2 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: plotly>=5.24.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.5.2 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 12)) (1.6.1)
# Requirement already satisfied: scipy>=1.14.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 13)) (1.15.3)
# Requirement already satisfied: xgboost>=2.1.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: et_xmlfile in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from openpyxl->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.9.2->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from plotly>=5.24.1->-r requirements.txt (line 9)) (9.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.5.2->-r requirements.txt (line 12)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.5.2->-r requirements.txt (line 12)) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/mikevoeten/anaconda/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# General
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import re

# Visualisations
import matplotlib.pyplot as pltå
import seaborn as sns
import plotly.express as px
import matplotlib.ticker as mtick

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score, KFold, cross_val_predict
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from scipy.stats import ttest_rel, wilcoxon, pearsonr
from sklearn.ensemble import IsolationForest
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
magic_number = sum([ord(x) for x in "Make Moni Flow"])

SEED = magic_number
TEST_SIZE = 0.2
RANDOM_STATE = magic_number
print(magic_number)
# Out:
# 1257

# %%
raw_data = "./src/Keessmit_raw.xlsx"
data = pd.read_excel(raw_data)
data.head()
# Out:
#    productID                                    productName productPrice  \
# 0     1000.0  Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen          NaN
# 1   100365.0                  Hartman Da Vinci standenstoel        295,-
# 2    10060.0          Shadowline Parasol beschermhoes Small        29.95
# 3    10061.0         Shadowline Parasol beschermhoes Medium        33.95
# 4    10062.0          Shadowline Parasol beschermhoes Large        37.95
#
#    productVAT productDiscount       productColor  \
# 0         NaN             NaN              Groen
# 1         NaN          (-15%)  Grijs - Antraciet
# 2         NaN          (-19%)  Grijs - Antraciet
# 3         NaN          (-14%)  Grijs - Antraciet
# 4         NaN          (-10%)  Grijs - Antraciet
#
#                                      productCategory          productBrand  \
# 0  \n                    Tuinaccessoires         ...   Kees Smit Collectie
# 1  \n                    Tuinstoelen                  Hartman tuinmeubelen
# 2     \n                    Parasols                            Shadowline
# 3     \n                    Parasols                            Shadowline
# 4     \n                    Parasols                            Shadowline
#
#    productURL               currentDate  \
# 0         NaN  2025-08-12T09:38:53.862Z
# 1         NaN  2025-08-12T09:38:53.982Z
# 2         NaN  2025-08-12T09:38:54.099Z
# 3         NaN  2025-08-12T09:38:54.214Z
# 4         NaN  2025-08-12T09:38:54.308Z
#
#                                                  url
# 0  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2  https://www.keessmit.nl/shadowline-parasol-bes...
# 3  https://www.keessmit.nl/shadowline-parasol-bes...
# 4  https://www.keessmit.nl/shadowline-parasol-bes...

# %% [markdown]
# ---
#
# # **5.0 - Dataset Cleaning**
#
# ---

# %%
data.describe()
# Out:
#            productID  productVAT  productURL
# count    4519.000000         0.0         0.0
# mean   121903.757911         NaN         NaN
# std      8118.953139         NaN         NaN
# min      1000.000000         NaN         NaN
# 25%    118988.500000         NaN         NaN
# 50%    124318.000000         NaN         NaN
# 75%    126379.000000         NaN         NaN
# max    128388.000000         NaN         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4520 entries, 0 to 4519
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   productID        4519 non-null   float64
#  1   productName      4520 non-null   object
#  2   productPrice     4135 non-null   object
#  3   productVAT       0 non-null      float64
#  4   productDiscount  3873 non-null   object
#  5   productColor     2800 non-null   object
#  6   productCategory  4519 non-null   object
#  7   productBrand     4510 non-null   object
#  8   productURL       0 non-null      float64
#  9   currentDate      4520 non-null   object
#  10  url              4520 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 388.6+ KB

# %%
data = data.drop(columns=["productVAT", "productURL", "currentDate"])
data.head()
# Out:
#    productID                                    productName productPrice  \
# 0     1000.0  Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen          NaN
# 1   100365.0                  Hartman Da Vinci standenstoel        295,-
# 2    10060.0          Shadowline Parasol beschermhoes Small        29.95
# 3    10061.0         Shadowline Parasol beschermhoes Medium        33.95
# 4    10062.0          Shadowline Parasol beschermhoes Large        37.95
#
#   productDiscount       productColor  \
# 0             NaN              Groen
# 1          (-15%)  Grijs - Antraciet
# 2          (-19%)  Grijs - Antraciet
# 3          (-14%)  Grijs - Antraciet
# 4          (-10%)  Grijs - Antraciet
#
#                                      productCategory          productBrand  \
# 0  \n                    Tuinaccessoires         ...   Kees Smit Collectie
# 1  \n                    Tuinstoelen                  Hartman tuinmeubelen
# 2     \n                    Parasols                            Shadowline
# 3     \n                    Parasols                            Shadowline
# 4     \n                    Parasols                            Shadowline
#
#                                                  url
# 0  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2  https://www.keessmit.nl/shadowline-parasol-bes...
# 3  https://www.keessmit.nl/shadowline-parasol-bes...
# 4  https://www.keessmit.nl/shadowline-parasol-bes...

# %%
def clean_text(text):
    if pd.isna(text): return ""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

data['productName_clean'] = data['productName'].apply(clean_text)
data['productName_clean'] = data['productName_clean'].str.replace(r'\b\w\b', '', regex=True)
data['productName_clean'] = data['productName_clean'].str.replace(r'\s+', ' ', regex=True).str.strip()
data['productName_clean'] = data['productName_clean'].astype(str)

# %%
def clean_price(price):
    if pd.isna(price): return None
    price_str = str(price).strip()
    price_str = re.sub(r"[,-]+$", "", price_str)
    if re.match(r"^\d{1,3}(\.\d{3})*,\d{1,2}$", price_str):
        price_str = price_str.replace(".", "").replace(",", ".")
    elif "," in price_str and "." not in price_str:
        price_str = price_str.replace(",", ".")
    elif re.match(r"^\d{1,3}(\.\d{3})*$", price_str):
        price_str = price_str.replace(".", "")
    try: return round(float(price_str), 2)
    except ValueError: return None

data['productPrice'] = data['productPrice'].apply(clean_price).fillna(0)

# %%
data['productDiscount'] = data['productDiscount'].str.replace(r'[^\d.]', '', regex=True)
data['productDiscount'] = data['productDiscount'].replace('', '0').astype(float) / 100
data['productDiscount'] = data['productDiscount'].fillna(0)
data['productDiscount'].head(20)
# Out:
# 0     0.00
# 1     0.15
# 2     0.19
# 3     0.14
# 4     0.10
# 5     0.10
# 6     0.15
# 7     0.25
# 8     0.21
# 9     0.17
# 10    0.13
# 11    0.17
# 12    0.18
# 13    0.00
# 14    0.00
# 15    0.00
# 16    0.48
# 17    0.00
# 18    0.00
# 19    0.00
# Name: productDiscount, dtype: float64

# %%
data['productColor'] = data['productColor'].str.strip()                  # remove leading/trailing whitespace
data['productColor'] = data['productColor'].replace(r'\s+', ' ', regex=True)  # replace multiple spaces/newlines with single space
print(data['productColor'].unique())
print(len(data['productColor'].unique()))
# Out:
# ['Groen' 'Grijs - Antraciet' 'Zwart' 'Taupe - Naturel - Bruin' nan
#  'Old Teak Greywash' 'Wit - Ecru' 'Grijs - Antraciet, Zwart' 'Zwart, Rood'
#  'Grijs - Antraciet, Wit - Ecru' 'Groen, Taupe - Naturel - Bruin'
#  'Zwart, Natural Teak' 'Grijs - Antraciet, Natural Teak'
#  'Wit - Ecru, Natural Teak' 'Rood' 'Blauw, Grijs - Antraciet' 'Geel'
#  'Roze' 'Grijs - Antraciet, Old Teak Greywash'
#  'Wit - Ecru, Old Teak Greywash' 'Natural Teak' 'Groen, Natural Teak'
#  'Taupe - Naturel - Bruin, Old Teak Greywash' 'Zwart, Old Teak Greywash'
#  'Taupe - Naturel - Bruin, Zwart'
#  'Grijs - Antraciet, Taupe - Naturel - Bruin, Zwart' 'Blauw'
#  'Taupe - Naturel - Bruin, Zwart, Natural Teak' 'Groen, Old Teak Greywash'
#  'Oranje, Rood' 'Grijs - Antraciet, Groen, Natural Teak'
#  'Grijs - Antraciet, Wit - Ecru, Natural Teak' 'Blauw, Groen'
#  'Taupe - Naturel - Bruin, Wit - Ecru, Natural Teak'
#  'Grijs - Antraciet, Roze' 'Blauw, Taupe - Naturel - Bruin, Wit - Ecru'
#  'Roze, Rood' 'Blauw, Zwart' 'Wit - Ecru, Zwart'
#  'Blauw, Old Teak Greywash' 'Taupe - Naturel - Bruin, Wit - Ecru'
#  'Blauw, Taupe - Naturel - Bruin, Rood'
#  'Grijs - Antraciet, Taupe - Naturel - Bruin' 'Groen, Zwart'
#  'Grijs - Antraciet, Groen' 'Paars' 'Groen, Roze' 'Roze, Paars'
#  'Natural Teak, Rood' 'Oranje' 'Wit - Ecru, Oranje' 'Groen, Wit - Ecru'
#  'Grijs - Antraciet, Zwart, Old Teak Greywash'
#  'Blauw, Groen, Taupe - Naturel - Bruin'
#  'Grijs - Antraciet, Taupe - Naturel - Bruin, Oranje, Rood'
#  'Blauw, Wit - Ecru' 'Roze, Wit - Ecru' 'Groen, Roze, Oranje, Rood'
#  'Blauw, Oranje, Rood' 'Groen, Oranje, Rood' 'Blauw, Geel'
#  'Grijs - Antraciet, Roze, Zwart' 'Grijs - Antraciet, Oranje, Rood'
#  'Blauw, Groen, Geel' 'Grijs - Antraciet, Roze, Rood'
#  'Grijs - Antraciet, Taupe - Naturel - Bruin, Wit - Ecru'
#  'Grijs - Antraciet, Taupe - Naturel - Bruin, Natural Teak'
#  'Blauw, Wit - Ecru, Oranje' 'Roze, Wit - Ecru, Geel, Rood'
#  'Grijs - Antraciet, Groen, Roze, Taupe - Naturel - Bruin'
#  'Wit - Ecru, Geel, Oranje, Rood' 'Blauw, Groen, Zwart'
#  'Geel, Oranje, Rood' 'Blauw, Grijs - Antraciet, Taupe - Naturel - Bruin'
#  'Grijs - Antraciet, Groen, Taupe - Naturel - Bruin'
#  'Blauw, Grijs - Antraciet, Roze' 'Groen, Geel, Oranje'
#  'Grijs - Antraciet, Geel, Oranje, Rood'
#  'Blauw, Grijs - Antraciet, Roze, Wit - Ecru'
#  'Blauw, Grijs - Antraciet, Old Teak Greywash'
#  'Grijs - Antraciet, Zwart, Natural Teak']
# 81

# %%
data['productCategory'] = data['productCategory'].str.replace(r'\s+', ' ', regex=True).str.strip()
data['productCategory'].head(20)
# Out:
# 0     Tuinaccessoires
# 1         Tuinstoelen
# 2            Parasols
# 3            Parasols
# 4            Parasols
# 5            Parasols
# 6     Tuinaccessoires
# 7     Tuinaccessoires
# 8           Ligbedden
# 9            Parasols
# 10           Parasols
# 11           Parasols
# 12           Parasols
# 13           Parasols
# 14        Tuinkussens
# 15        Tuinkussens
# 16        Tuinkussens
# 17        Tuinkussens
# 18        Tuinkussens
# 19        Tuinkussens
# Name: productCategory, dtype: object

# %%
data['productBrand'] = data['productBrand'].str.lower().str.strip().str.replace("&amp;", "&")
data['productBrand'].head(20)
# Out:
# 0      kees smit collectie
# 1     hartman tuinmeubelen
# 2               shadowline
# 3               shadowline
# 4               shadowline
# 5               shadowline
# 6     hartman tuinmeubelen
# 7     hartman tuinmeubelen
# 8     hartman tuinmeubelen
# 9      kees smit collectie
# 10     kees smit collectie
# 11     kees smit collectie
# 12     kees smit collectie
# 13                   glatz
# 14                 madison
# 15                 madison
# 16                 madison
# 17                 madison
# 18                 madison
# 19                 madison
# Name: productBrand, dtype: object

# %%
data.head()
# Out:
#    productID                                    productName  productPrice  \
# 0     1000.0  Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen          0.00
# 1   100365.0                  Hartman Da Vinci standenstoel        295.00
# 2    10060.0          Shadowline Parasol beschermhoes Small         29.95
# 3    10061.0         Shadowline Parasol beschermhoes Medium         33.95
# 4    10062.0          Shadowline Parasol beschermhoes Large         37.95
#
#    productDiscount       productColor  productCategory          productBrand  \
# 0             0.00              Groen  Tuinaccessoires   kees smit collectie
# 1             0.15  Grijs - Antraciet      Tuinstoelen  hartman tuinmeubelen
# 2             0.19  Grijs - Antraciet         Parasols            shadowline
# 3             0.14  Grijs - Antraciet         Parasols            shadowline
# 4             0.10  Grijs - Antraciet         Parasols            shadowline
#
#                                                  url  \
# 0  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2  https://www.keessmit.nl/shadowline-parasol-bes...
# 3  https://www.keessmit.nl/shadowline-parasol-bes...
# 4  https://www.keessmit.nl/shadowline-parasol-bes...
#
#                         productName_clean
# 0     cadeaubon 20 kees smit tuinmeubelen
# 1           hartman da vinci standenstoel
# 2   shadowline parasol beschermhoes small
# 3  shadowline parasol beschermhoes medium
# 4   shadowline parasol beschermhoes large

# %% [markdown]
# ---
#
# # **6.0 - Feature Engineering**
#
# ---

# %% [markdown]
# ## Product Name Comparisons (TF-IDF + Clustering)

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(data['productName_clean'])
X_name = vectorizer.transform(data['productName_clean'])

# %%
k_name = 100  #TODO: think of smarter way to select clusters given complexity. This is just the approx different cats.
kmeans_name = KMeans(n_clusters=k_name, random_state=RANDOM_STATE)
data['name_cluster'] = kmeans_name.fit_predict(X_name)

# %%
data.head(100)
# Out:
#     productID                                        productName  \
# 0      1000.0      Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen
# 1    100365.0                      Hartman Da Vinci standenstoel
# 2     10060.0              Shadowline Parasol beschermhoes Small
# 3     10061.0             Shadowline Parasol beschermhoes Medium
# 4     10062.0              Shadowline Parasol beschermhoes Large
# ..        ...                                                ...
# 95   105737.0              ROUGH-S Adirondack schommelbank 110cm
# 96   105742.0                             ROUGH-O tuinbank 150cm
# 97   105902.0                       ROUGH-X 180cm barset 7-delig
# 98   105911.0  ROUGH-S/ROUGH-X 180cm dining tuinset 5-delig s...
# 99   105914.0  ROUGH-S/ROUGH-X 200cm dining tuinset 4-delig s...
#
#     productPrice  productDiscount       productColor  productCategory  \
# 0           0.00             0.00              Groen  Tuinaccessoires
# 1         295.00             0.15  Grijs - Antraciet      Tuinstoelen
# 2          29.95             0.19  Grijs - Antraciet         Parasols
# 3          33.95             0.14  Grijs - Antraciet         Parasols
# 4          37.95             0.10  Grijs - Antraciet         Parasols
# ..           ...              ...                ...              ...
# 95        669.95             0.20  Old Teak Greywash       Tuinbanken
# 96        799.95             0.20  Old Teak Greywash       Tuinbanken
# 97          0.00             0.00                NaN         Tuinsets
# 98       1369.00             0.26                NaN         Tuinsets
# 99       1399.00             0.28                NaN         Tuinsets
#
#             productBrand                                                url  \
# 0    kees smit collectie  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1   hartman tuinmeubelen  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 3             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 4             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# ..                   ...                                                ...
# 95       rough furniture  https://www.keessmit.nl/rough-s-adirondack-sch...
# 96       rough furniture  https://www.keessmit.nl/rough-o-tuinbank-150cm...
# 97       rough furniture  https://www.keessmit.nl/rough-x-180cm-barset-7...
# 98       rough furniture  https://www.keessmit.nl/rough-s-rough-x-180cm-...
# 99       rough furniture  https://www.keessmit.nl/rough-s-rough-x-200cm-...
#
#                                     productName_clean  name_cluster
# 0                 cadeaubon 20 kees smit tuinmeubelen            70
# 1                       hartman da vinci standenstoel             9
# 2               shadowline parasol beschermhoes small             9
# 3              shadowline parasol beschermhoes medium             9
# 4               shadowline parasol beschermhoes large             9
# ..                                                ...           ...
# 95                rough adirondack schommelbank 110cm             9
# 96                               rough tuinbank 150cm            24
# 97                           rough 180cm barset delig            60
# 98  rough rough 180cm dining tuinset delig stapelbaar            78
# 99  rough rough 200cm dining tuinset delig stapelbaar            78
#
# [100 rows x 10 columns]

# %%
cluster_products = data[data['name_cluster'] == 3]
cluster_products['productName_clean']
# Out:
# 21        madison tuinkussen kuip 48x46cm zit
# 22      madison kuip tuinkussens hoog 96x45cm
# 391     madison kuip tuinkussens hoog 96x45cm
# 392     madison kuip tuinkussens hoog 96x45cm
# 393     madison kuip tuinkussens hoog 96x45cm
# 394     madison kuip tuinkussens hoog 96x45cm
# 395     madison kuip tuinkussens hoog 96x45cm
# 416      madison tuinkussens kuip 48x46cm zit
# 417       madison tuinkussen kuip 48x46cm zit
# 3843      madison tuinkussen kuip 48x46cm zit
# 3844      madison tuinkussen kuip 48x46cm zit
# 3845      madison tuinkussen kuip 48x46cm zit
# 3846      madison tuinkussen kuip 48x46cm zit
# 3847      madison tuinkussen kuip 48x46cm zit
# Name: productName_clean, dtype: object

# %%
cluster_counts = data['name_cluster'].value_counts().sort_index()
cluster_table = cluster_counts.reset_index()
cluster_table.columns = ['cluster_id', 'num_products']
print(cluster_table)
# Out:
#     cluster_id  num_products
# 0            0            74
# 1            1            34
# 2            2            18
# 3            3            14
# 4            4            25
# ..         ...           ...
# 95          95            54
# 96          96            39
# 97          97            15
# 98          98            23
# 99          99            38
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Product Name Comparisons (Word Count + Clustering)

# %%
count_vectorizer = CountVectorizer()
X_count = count_vectorizer.fit_transform(data['productName_clean'])

# %%
k_count = 100  
kmeans_count = KMeans(n_clusters=k_count, random_state=RANDOM_STATE)
data['name_cluster_count'] = kmeans_count.fit_predict(X_count)

# %%
cluster_counts = data['name_cluster_count'].value_counts().sort_index()
cluster_table = cluster_counts.reset_index()
cluster_table.columns = ['cluster_id', 'num_products']
print(cluster_table)
# Out:
#     cluster_id  num_products
# 0            0           120
# 1            1            57
# 2            2           120
# 3            3            75
# 4            4            41
# ..         ...           ...
# 95          95            16
# 96          96            25
# 97          97            10
# 98          98            13
# 99          99            15
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Product Name Comparisons (TF-IDF + Word Count + Clustering)

# %%
count_vectorizer = CountVectorizer()
X_count2 = count_vectorizer.fit_transform(data['productName_clean'])
vectorizer = TfidfVectorizer()
vectorizer.fit(data['productName_clean'])
X_name2 = vectorizer.transform(data['productName_clean'])
X_combined = hstack([X_name2, X_count2])

# %%
k_combined = 100
kmeans_combined = KMeans(n_clusters=k_combined, random_state=RANDOM_STATE)
data['name_cluster_combined'] = kmeans_combined.fit_predict(X_combined)

# %%
cluster_counts = data['name_cluster_combined'].value_counts().sort_index()
cluster_table = cluster_counts.reset_index()
cluster_table.columns = ['cluster_id', 'num_products']
print(cluster_table)
# Out:
#     cluster_id  num_products
# 0            0            97
# 1            1           105
# 2            2            93
# 3            3            33
# 4            4            96
# ..         ...           ...
# 95          95            10
# 96          96            21
# 97          97            26
# 98          98            30
# 99          99            28
#
# [100 rows x 2 columns]

# %%
cluster_products = data[data['name_cluster_combined'] == 95]
cluster_products['productName_clean']
# Out:
# 1074    il tempo di sotto lounge voetenbank 66x66cm
# 1075    il tempo del capo lounge voetenbank 66x66cm
# 2292         il tempo cira lounge tussenmodule 70cm
# 2293         il tempo cira lounge tussenmodule 70cm
# 2294           il tempo cira lounge hoekmodule 90cm
# 2295           il tempo cira lounge hoekmodule 90cm
# 2296        il tempo cira lounge voetenbank 90x90cm
# 2297        il tempo cira lounge voetenbank 90x90cm
# 2298               il tempo giulia lounge tuinstoel
# 3106    il tempo giulia lounge tuintafel 100cm 40cm
# Name: productName_clean, dtype: object

# %%
data.head(20)
# Out:
#     productID                                        productName  \
# 0      1000.0      Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen
# 1    100365.0                      Hartman Da Vinci standenstoel
# 2     10060.0              Shadowline Parasol beschermhoes Small
# 3     10061.0             Shadowline Parasol beschermhoes Medium
# 4     10062.0              Shadowline Parasol beschermhoes Large
# 5     10063.0          Shadowline Zweefparasol beschermhoes Boog
# 6    100819.0              Hartman Da Vinci voetenbank 2 standen
# 7    100822.0                          Hartman Garden voetenbank
# 8    100825.0                   Hartman Da Vinci ligbed met wiel
# 9    100848.0                             Parasolvoet 25kg beton
# 10   100849.0                             Parasolvoet 30kg beton
# 11   100850.0                    Parasolvoet 38kg beton met wiel
# 12   100864.0                             Parasolvoet 35kg beton
# 13   100920.0  Glatz Bodemhuls M4 t.b.v. Glatz Sombrano/Forte...
# 14   101123.0         Madison tuinkussen voor deckchair 200x50cm
# 15   101164.0            Madison tuinkussen voor ligbed 200x65cm
# 16   101179.0    Madison Hocker/tuinkussens 55x55cm met rand zit
# 17   101180.0    Madison Hocker/tuinkussens 55x55cm met rand zit
# 18   101203.0   Madison Wicker Universeel tuinkussen 48x48cm zit
# 19   101219.0        Madison Wicker Multi tuinkussen 48x48cm zit
#
#     productPrice  productDiscount             productColor  productCategory  \
# 0           0.00             0.00                    Groen  Tuinaccessoires
# 1         295.00             0.15        Grijs - Antraciet      Tuinstoelen
# 2          29.95             0.19        Grijs - Antraciet         Parasols
# 3          33.95             0.14        Grijs - Antraciet         Parasols
# 4          37.95             0.10        Grijs - Antraciet         Parasols
# 5          44.95             0.10        Grijs - Antraciet         Parasols
# 6         295.00             0.15        Grijs - Antraciet  Tuinaccessoires
# 7         149.95             0.25        Grijs - Antraciet  Tuinaccessoires
# 8          54.00             0.21        Grijs - Antraciet        Ligbedden
# 9          49.00             0.17        Grijs - Antraciet         Parasols
# 10         69.00             0.13        Grijs - Antraciet         Parasols
# 11         99.00             0.17        Grijs - Antraciet         Parasols
# 12         89.00             0.18        Grijs - Antraciet         Parasols
# 13          0.00             0.00        Grijs - Antraciet         Parasols
# 14         54.00             0.00                    Zwart      Tuinkussens
# 15         54.00             0.00                    Zwart      Tuinkussens
# 16         11.95             0.48  Taupe - Naturel - Bruin      Tuinkussens
# 17         54.00             0.00                    Zwart      Tuinkussens
# 18         54.00             0.00                    Zwart      Tuinkussens
# 19         54.00             0.00                    Zwart      Tuinkussens
#
#             productBrand                                                url  \
# 0    kees smit collectie  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1   hartman tuinmeubelen  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 3             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 4             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 5             shadowline  https://www.keessmit.nl/shadowline-zweefparaso...
# 6   hartman tuinmeubelen  https://www.keessmit.nl/hartman-da-vinci-voete...
# 7   hartman tuinmeubelen  https://www.keessmit.nl/hartman-garden-voetenb...
# 8   hartman tuinmeubelen  https://www.keessmit.nl/hartman-da-vinci-ligbe...
# 9    kees smit collectie  https://www.keessmit.nl/parasolvoet-25kg-beton...
# 10   kees smit collectie  https://www.keessmit.nl/parasolvoet-30kg-beton...
# 11   kees smit collectie  https://www.keessmit.nl/parasolvoet-38kg-beton...
# 12   kees smit collectie  https://www.keessmit.nl/parasolvoet-35kg-beton...
# 13                 glatz  https://www.keessmit.nl/glatz-bodemhuls-m4-t-b...
# 14               madison  https://www.keessmit.nl/madison-tuinkussen-voo...
# 15               madison  https://www.keessmit.nl/madison-tuinkussen-voo...
# 16               madison  https://www.keessmit.nl/madison-hocker-tuinkus...
# 17               madison  https://www.keessmit.nl/madison-hocker-tuinkus...
# 18               madison  https://www.keessmit.nl/madison-wicker-univers...
# 19               madison  https://www.keessmit.nl/madison-wicker-multi-t...
#
#                                    productName_clean  name_cluster  \
# 0                cadeaubon 20 kees smit tuinmeubelen            70
# 1                      hartman da vinci standenstoel             9
# 2              shadowline parasol beschermhoes small             9
# 3             shadowline parasol beschermhoes medium             9
# 4              shadowline parasol beschermhoes large             9
# 5          shadowline zweefparasol beschermhoes boog             9
# 6                hartman da vinci voetenbank standen            53
# 7                          hartman garden voetenbank            53
# 8                   hartman da vinci ligbed met wiel            39
# 9                             parasolvoet 25kg beton             9
# 10                            parasolvoet 30kg beton             9
# 11                   parasolvoet 38kg beton met wiel             9
# 12                            parasolvoet 35kg beton             9
# 13    glatz bodemhuls m4 glatz sombrano fortello led            34
# 14        madison tuinkussen voor deckchair 200x50cm            26
# 15           madison tuinkussen voor ligbed 200x65cm            26
# 16   madison hocker tuinkussens 55x55cm met rand zit            63
# 17   madison hocker tuinkussens 55x55cm met rand zit            63
# 18  madison wicker universeel tuinkussen 48x48cm zit            90
# 19       madison wicker multi tuinkussen 48x48cm zit            90
#
#     name_cluster_count  name_cluster_combined
# 0                   51                     82
# 1                   13                     23
# 2                    6                      6
# 3                    6                      6
# 4                    6                      6
# 5                   18                     26
# 6                   13                     23
# 7                   13                     23
# 8                   67                     23
# 9                   13                     23
# 10                  13                     23
# 11                  67                     23
# 12                  13                     23
# 13                  99                     70
# 14                   5                     14
# 15                  72                     92
# 16                  26                     56
# 17                  26                     56
# 18                  62                      5
# 19                  62                      5

# %% [markdown]
# ## Clustering for Anomaly Detection

# %%
features = [
    'productPrice',
    'productDiscount',
    'name_cluster',
    'name_cluster_count',
    'name_cluster_combined'
]

X = data[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
k_final = 100
kmeans_final = KMeans(n_clusters=k_final, random_state=RANDOM_STATE)
data['final_cluster'] = kmeans_final.fit_predict(X_scaled)

# %%
distances = kmeans_final.transform(X_scaled)
data['anomaly_score'] = np.min(distances, axis=1)

# %%
threshold = data['anomaly_score'].mean() + 3 * data['anomaly_score'].std()
data['is_anomaly'] = data['anomaly_score'] > threshold

# %%
data.head(100)
# Out:
#     productID                                        productName  \
# 0      1000.0      Cadeaubon t.w.v. €20,- Kees Smit Tuinmeubelen
# 1    100365.0                      Hartman Da Vinci standenstoel
# 2     10060.0              Shadowline Parasol beschermhoes Small
# 3     10061.0             Shadowline Parasol beschermhoes Medium
# 4     10062.0              Shadowline Parasol beschermhoes Large
# ..        ...                                                ...
# 95   105737.0              ROUGH-S Adirondack schommelbank 110cm
# 96   105742.0                             ROUGH-O tuinbank 150cm
# 97   105902.0                       ROUGH-X 180cm barset 7-delig
# 98   105911.0  ROUGH-S/ROUGH-X 180cm dining tuinset 5-delig s...
# 99   105914.0  ROUGH-S/ROUGH-X 200cm dining tuinset 4-delig s...
#
#     productPrice  productDiscount       productColor  productCategory  \
# 0           0.00             0.00              Groen  Tuinaccessoires
# 1         295.00             0.15  Grijs - Antraciet      Tuinstoelen
# 2          29.95             0.19  Grijs - Antraciet         Parasols
# 3          33.95             0.14  Grijs - Antraciet         Parasols
# 4          37.95             0.10  Grijs - Antraciet         Parasols
# ..           ...              ...                ...              ...
# 95        669.95             0.20  Old Teak Greywash       Tuinbanken
# 96        799.95             0.20  Old Teak Greywash       Tuinbanken
# 97          0.00             0.00                NaN         Tuinsets
# 98       1369.00             0.26                NaN         Tuinsets
# 99       1399.00             0.28                NaN         Tuinsets
#
#             productBrand                                                url  \
# 0    kees smit collectie  https://www.keessmit.nl/cadeaubon-t-w-v-20-kee...
# 1   hartman tuinmeubelen  https://www.keessmit.nl/hartman-da-vinci-stand...
# 2             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 3             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# 4             shadowline  https://www.keessmit.nl/shadowline-parasol-bes...
# ..                   ...                                                ...
# 95       rough furniture  https://www.keessmit.nl/rough-s-adirondack-sch...
# 96       rough furniture  https://www.keessmit.nl/rough-o-tuinbank-150cm...
# 97       rough furniture  https://www.keessmit.nl/rough-x-180cm-barset-7...
# 98       rough furniture  https://www.keessmit.nl/rough-s-rough-x-180cm-...
# 99       rough furniture  https://www.keessmit.nl/rough-s-rough-x-200cm-...
#
#                                     productName_clean  name_cluster  \
# 0                 cadeaubon 20 kees smit tuinmeubelen            70
# 1                       hartman da vinci standenstoel             9
# 2               shadowline parasol beschermhoes small             9
# 3              shadowline parasol beschermhoes medium             9
# 4               shadowline parasol beschermhoes large             9
# ..                                                ...           ...
# 95                rough adirondack schommelbank 110cm             9
# 96                               rough tuinbank 150cm            24
# 97                           rough 180cm barset delig            60
# 98  rough rough 180cm dining tuinset delig stapelbaar            78
# 99  rough rough 200cm dining tuinset delig stapelbaar            78
#
#     name_cluster_count  name_cluster_combined  final_cluster  anomaly_score  \
# 0                   51                     82             47       0.261398
# 1                   13                     23             41       0.577274
# 2                    6                      6              0       0.834130
# 3                    6                      6              0       1.084326
# 4                    6                      6             25       0.916995
# ..                 ...                    ...            ...            ...
# 95                  55                     41             82       0.614271
# 96                  55                     41             82       0.714381
# 97                  68                     67             39       0.624515
# 98                  59                     32             54       0.873935
# 99                  59                     32             52       0.788432
#
#     is_anomaly
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 95       False
# 96       False
# 97       False
# 98       False
# 99       False
#
# [100 rows x 15 columns]

# %%
anomalies = data[data['is_anomaly']]
print(len(anomalies))
# Out:
# 34

# %%
output_path = "./output/anomalies.xlsx"

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    anomalies.to_excel(writer, sheet_name="Anomalies", index=False)
